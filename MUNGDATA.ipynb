# %% [markdown]
# <a href="https://colab.research.google.com/github/cwave-org/MUNG/blob/main/MUNGDATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/Shareddrives/한남동클라쓰/MUNG/라벨링 데이터
# Out:
# /content/drive/Shareddrives/한남동클라쓰/MUNG/라벨링 데이터

# %%
import pandas as pd

# %%
from glob import glob
for filename in glob('*.json'):
  print(filename)
# Out:
# B_10_CHI_SF_20221116_10_000929_13.json
# B_10_CHI_SF_20221116_10_000929_08.json
# B_10_CHI_SF_20221116_10_000929_05.json
# B_10_CHI_SF_20221116_10_000929_07.json
# B_10_CHI_SF_20221116_10_000929_16.json
# B_10_CHI_SF_20221116_10_000929_04.json
# B_10_CHI_SF_20221116_10_000929_02.json
# B_10_CHI_SF_20221116_10_000929_10.json
# B_10_CHI_SF_20221116_10_000929_11.json
# B_10_CHI_SF_20221116_10_000929_09.json
# B_10_CHI_SF_20221116_10_000929_06.json
# B_10_CHI_SF_20221116_10_000929_12.json
# B_10_CHI_SF_20221116_10_000929_03.json
# B_10_CHI_SF_20221116_10_000929_14.json
# B_10_CHI_SF_20221116_10_000929_17.json
# B_10_CHI_SF_20221116_10_000929_01.json
# B_10_CHI_SF_20221116_10_000929_15.json
# B_10_CHI_SF_20221116_10_000929_19.json
# B_10_CHI_SF_20221117_10_000957_09.json
# B_10_CHI_SF_20221116_10_000929_20.json
# B_10_CHI_SF_20221117_10_000957_13.json
# B_10_CHI_SF_20221117_10_000957_03.json
# B_10_CHI_SF_20221117_10_000957_06.json
# B_10_CHI_SF_20221117_10_000957_11.json
# ...

# %%
from IPython.display import display

def preview():
  for filename in glob('*.json'):
    df = pd.read_json(filename)
    print(filename, df.shape)
    display(df.head(10))
    print('\n')
    
preview()
# Out:
# B_10_CHI_SF_20221116_10_000929_13.json (9, 2)
#                                                    metadata  \
# type                                                      B
# id        {'species': '10', 'mission-id': '10_000929', '...
# physical  {'weight': 2.5, 'shoulder-height': 19, 'neck-s...
# image                                   {'body-part': '13'}
# breeding  {'exercise': 2, 'food-count': 4, 'environment'...
# medical   {'disease': 'ABN', 'diseaseName': 'CAR', 'CRP'...
# vital     {'heart-rate': 142, 'breating-rate': 33, 'body...
# image-id                                                NaN
# label                                                   NaN
#
#                                                 annotations
# type                                                    NaN
# id                                                      NaN
# physical                                                NaN
# image                                                   NaN
# ...

# %%
for filename in glob('*.json'):
  df = pd.read_json(filename)
  print(filename, df.shape)
  display(df.head(10))
  print('\n')
# Out:
# B_10_CHI_SF_20221116_10_000929_13.json (9, 2)
#                                                    metadata  \
# type                                                      B
# id        {'species': '10', 'mission-id': '10_000929', '...
# physical  {'weight': 2.5, 'shoulder-height': 19, 'neck-s...
# image                                   {'body-part': '13'}
# breeding  {'exercise': 2, 'food-count': 4, 'environment'...
# medical   {'disease': 'ABN', 'diseaseName': 'CAR', 'CRP'...
# vital     {'heart-rate': 142, 'breating-rate': 33, 'body...
# image-id                                                NaN
# label                                                   NaN
#
#                                                 annotations
# type                                                    NaN
# id                                                      NaN
# physical                                                NaN
# image                                                   NaN
# ...

# %%
df['metadata']['vital']
# Out:
# {'heart-rate': 84, 'breating-rate': 24, 'body-heat': 39, 'stress': 1.3}

# %%
for filename in glob('*.json'):
  df3 = pd.read_json(filename)
  df4=pd.json_normalize(df3['metadata']['vital'])
  #display(df.head(10))
  print(df4)
# Out:
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
# ...

# %%
for filename in glob('*01.json'):
  data3 = pd.read_json(filename)
  data4=pd.json_normalize(data3['metadata']['vital'])
  #display(df.head(10))
  print(data4)
# Out:
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33       38.1     8.6
#    heart-rate  breating-rate  body-heat  stress
# 0         110             36         40     3.6
#    heart-rate  breating-rate  body-heat  stress
# 0         108             24       38.9     1.3
#    heart-rate  breating-rate  body-heat  stress
# 0         120             21       38.7     1.8
#    heart-rate  breating-rate  body-heat  stress
# 0         142             38       38.4     2.7
#    heart-rate  breating-rate  body-heat  stress
# 0         124             36       38.4     3.2
#    heart-rate  breating-rate  body-heat  stress
# 0         142             33         40     8.9
#    heart-rate  breating-rate  body-heat  stress
# 0          84             24         39     1.3

# %%
real2=pd.json_normalize(real['metadata'])

# %%
real2
# Out:
#   species mission-id provider-code breed  age class  sex  weight  \
# 0     NaN        NaN           NaN   NaN  NaN   NaN  NaN     NaN
# 1      10  10_001088          0010   POO  2.0    SS   CM     NaN
# 2     NaN        NaN           NaN   NaN  NaN   NaN  NaN     8.8
# 3     NaN        NaN           NaN   NaN  NaN   NaN  NaN     NaN
# 4     NaN        NaN           NaN   NaN  NaN   NaN  NaN     NaN
# 5     NaN        NaN           NaN   NaN  NaN   NaN  NaN     NaN
# 6     NaN        NaN           NaN   NaN  NaN   NaN  NaN     NaN
# 7     NaN        NaN           NaN   NaN  NaN   NaN  NaN     NaN
# 8     NaN        NaN           NaN   NaN  NaN   NaN  NaN     NaN
#
#    shoulder-height  neck-size  ...  food-kind  disease   CRP  lgG  IL-6   AFP  \
# 0              NaN        NaN  ...        NaN      NaN   NaN  NaN   NaN   NaN
# 1              NaN        NaN  ...        NaN      NaN   NaN  NaN   NaN   NaN
# 2             34.0       32.0  ...        NaN      NaN   NaN  NaN   NaN   NaN
# ...

# %%
real2['heart-rate']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6    84.0
# 7     NaN
# 8     NaN
# Name: heart-rate, dtype: float64
